# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt# data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
df = pd.read_csv("Aggregate_Expenditure.csv",encoding ='latin1')
df
# Out:
#                 State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0     Andhra Pradesh     1610    1831    1933    2588    3119    3413    4068
# 1   Arunachal Pradesh                                               251
# 2               Assam     758     618     691     942    1165    1207    1586
# 3               Bihar    1791    1871    1940    2144    2408    2966    3360
# 4        Chhattisgarh                                                 
# 5                 Goa                                               255
# 6             Gujarat    1442    1565    1949    2178    2463    2625    3323
# 7             Haryana     607     696     917     960    1120    1315    1509
# 8    Himachal Pradesh     338     297     353     385     479     588     648
# 9     Jammu & Kashmir     428     548     504     620     747     889     989
# 10          Jharkhand                                                 
# 11          Karnataka    1302    1409    1739    2002    2615    2894    3069
# 12             Kerala     855    1086     996    1322    1572    1969    2162
# 13     Madhya Pradesh    1590    1677    1938    2324    2522    2916    3349
# 14        Maharashtra    2613    3088    3585    4244    5063    5732    6412
# 15            Manipur     159     128     137     158     223     247     299
# 16          Meghalaya     102     101     117     139     161     188     230
# 17            Mizoram                                        177      55
# 18           Nagaland     164     132     166     215     202     272     344
# 19             Odisha     877     814    1191     997    1281    1410    1730
# 20             Punjab     817     996    1122    1434    1726    1963    1829
# 21          Rajasthan    1120    1360    1419    1585    1838    2116    2557
# 22             Sikkim      43      45      47      67      76     104     115
# 23         Tamil Nadu    1686    2006    2292    2752    2950    3309    3612
# 24          Telangana                                                 
# 25            Tripura     143     124     145     188     204     259     300
# 26      Uttar Pradesh    2668    2942    3490    4116    5186    5331    6225
# 27        Uttarakhand                                                 
# 28        West Bengal    1552    1838    2072    2181    2738    2974    3508
# 29              Delhi                                                 
# 30         Puducherry                                                 
#
#    1987-88 1988-89  ... 2006-07 2007-08    2008-09   2009-10    2010-11  \
# 0     4294    5223  ...   56648   74875   80803.89  85074.79  100635.64
# 1      348     326  ...    2786    3068    4272.59   5236.62    5579.12
# 2     1794    1855  ...   13485   15150   17485.86   24968.3   25946.97
# 3     3914    4324  ...   27136   31573   37181.25  42796.03   50704.52
# 4                 ...   11991   15029   17713.97  21558.72   23564.68
# 5      258     284  ...    3176    3559    4517.43   5524.45     6228.9
# 6     4089    4374  ...   39200   42681   51897.42  60335.23   71606.61
# 7     1663    1879  ...   19638   22079   26368.17  32561.93   34434.23
# 8      805     985  ...   10091   10614   12492.35  14030.92   16131.28
# 9     1269    1404  ...   13873   17046   18749.89  22518.56   25568.92
# 10                ...   15726   18360   20641.47  22712.77   26502.04
# 11    3437    3778  ...   44085   48031   54038.82  62963.51   71934.09
# 12    2251    2521  ...   23159   28692    32553.5  35833.48   40765.26
# 13    3932    4596  ...   30217   35265   40030.26  50032.45   60055.18
# 14    6929    8102  ...   75841   80240   99068.48  117431.1  130155.42
# 15     319     393  ...    3626    3720    4403.77   4725.83    6114.87
# 16     264     318  ...    2320    2771    3432.71   3833.36    4770.19
# 17     306     287  ...    2295    2559    2868.54   3529.02     4139.5
# 18     436     457  ...    3085    3563    3949.46    4520.1    5576.04
# 19    1990    2261  ...   19346   22844   30051.73  30540.64   36051.31
# 20    2623    2666  ...   26297   26519   28785.71  31307.95   37060.03
# 21    3384    3415  ...   31856   37757   42968.24  48749.81   53703.32
# 22     139     164  ...    2253    2820    2981.91   3509.84    3437.58
# 23    4196    4617  ...   51147   55748   67723.09  72730.33   90881.74
# 24                ...                                           
# 25     393     492  ...    3301    3835    4511.04   5757.51    5624.33
# 26    6901    8079  ...   74983   87304  104398.11  121115.3  134585.83
# 27                ...    8516    9975   10888.79  13297.14   14009.97
# 28    3941    4279  ...   41203   46644   60933.12  68134.03   72962.17
# 29                ...   12966   18160    20361.3  24925.92   25524.32
# 30                ...    2387    2588     2956.6   3585.83    4060.98
#
#       2011-12    2012-13    2013-14 2014-15 (RE) 2015-16 (BE)
# 0   115881.55  129440.92  136629.27    111067.46    112048.99
# 1     6665.17    6353.56    7781.63     11482.51     12712.91
# 2    30268.93   33747.64    37178.4     64979.96     63602.17
# 3    60180.03   69206.57   80405.17    132186.89    120685.32
# 4    28720.69   34819.25   39441.94     55979.35     65810.70
# 5     6953.57    7346.45     8149.5     10131.41     13102.77
# 6    79414.19   98281.32  104720.58    125490.25    137518.73
# 7    39751.43   46511.92   48928.65     63772.43     71674.80
# 8    17328.51   20714.59   21271.18     24894.61     28338.62
# 9    29856.23   31778.03    31908.7     42471.21     45919.52
# 10   26007.07   30399.82   30063.74     50839.55     55492.95
# 11   85756.16   96601.17   110648.7    132835.44    140534.43
# 12   53789.14   62032.26   69369.89     82947.71     99277.74
# 13   80658.96   83497.32   89764.16    123389.57    135972.07
# 14  148728.37  164202.42  186829.82    227932.63    240026.09
# 15    6862.64     6993.2    7172.92     11177.67      9652.41
# 16    5945.06     6123.4    6811.01     11893.17      9583.25
# 17    5638.11     5335.5    5635.93      7523.22      7576.53
# 18    6448.47    7194.14    7227.16      9241.40     10582.20
# 19    42105.1   47255.62   56130.92     76127.06     84487.77
# 20   36810.32   44507.28   47656.37     56430.95     61813.86
# 21   65372.08   81263.91   94101.08    125811.63    137713.39
# 22    3943.73    3930.92    4469.04      6716.29      5525.73
# 23  109465.27   121395.9  134192.38    161424.09    182338.58
# 24                                   99957.97    115059.19
# 25    6437.75    7027.49    7825.38     12399.45     14948.92
# 26  153712.31  173720.21  200720.05    262302.82    292687.32
# 27   16232.36   19216.41   21523.23     31455.80     31893.64
# 28   83830.88    95357.5  108513.39    129647.46    138374.00
# 29   26402.43   29858.81    34051.6     34790.00     41129.00
# 30    3756.01    3556.17    5050.33      5917.99      6431.00
#
# [31 rows x 37 columns]

# %%
rows,columns = df.shape
print("Rows: ",rows)
print("Columns: ",columns)
# Out:
# Rows:  31
# Columns:  37

# %%
for i in range(columns):
    print(str(i)+". :", df.iloc[:,i].dtype)
# Out:
# 0. : object
# 1. : object
# 2. : object
# 3. : object
# 4. : object
# 5. : object
# 6. : object
# 7. : object
# 8. : object
# 9. : object
# 10. : object
# 11. : object
# 12. : object
# 13. : object
# 14. : object
# 15. : object
# 16. : object
# 17. : object
# 18. : object
# 19. : object
# 20. : object
# 21. : object
# 22. : object
# 23. : object
# 24. : object
# 25. : object
# 26. : object
# 27. : object
# 28. : object
# 29. : object
# 30. : object
# 31. : object
# 32. : object
# 33. : object
# 34. : object
# 35. : float64
# 36. : float64

# %%
df.isna().sum()
# Out:
# State           0
# 1980-81         0
# 1981-82         0
# 1982-83         0
# 1983-84         0
# 1984-85         0
# 1985-86         0
# 1986-87         0
# 1987-88         0
# 1988-89         0
# 1989-90         0
# 1990-91         0
# 1991-92         0
# 1992-93         0
# 1993-94         0
# 1994-95         0
# 1995-96         0
# 1996-97         0
# 1997-98         0
# 1998-99         0
# 1999-00         0
# 2000-01         0
# 2001-02         0
# 2002-03         0
# 2003-04         0
# 2004-05         0
# 2005-06         0
# 2006-07         0
# 2007-08         0
# 2008-09         0
# 2009-10         0
# 2010-11         0
# 2011-12         0
# 2012-13         0
# 2013-14         0
# 2014-15 (RE)    0
# 2015-16 (BE)    0
# dtype: int64

# %%
df.replace({"":0},inplace=True)

# %%
df
# Out:
#                 State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0     Andhra Pradesh     1610    1831    1933    2588    3119    3413    4068
# 1   Arunachal Pradesh       0       0       0       0       0       0     251
# 2               Assam     758     618     691     942    1165    1207    1586
# 3               Bihar    1791    1871    1940    2144    2408    2966    3360
# 4        Chhattisgarh       0       0       0       0       0       0       0
# 5                 Goa       0       0       0       0       0       0     255
# 6             Gujarat    1442    1565    1949    2178    2463    2625    3323
# 7             Haryana     607     696     917     960    1120    1315    1509
# 8    Himachal Pradesh     338     297     353     385     479     588     648
# 9     Jammu & Kashmir     428     548     504     620     747     889     989
# 10          Jharkhand       0       0       0       0       0       0       0
# 11          Karnataka    1302    1409    1739    2002    2615    2894    3069
# 12             Kerala     855    1086     996    1322    1572    1969    2162
# 13     Madhya Pradesh    1590    1677    1938    2324    2522    2916    3349
# 14        Maharashtra    2613    3088    3585    4244    5063    5732    6412
# 15            Manipur     159     128     137     158     223     247     299
# 16          Meghalaya     102     101     117     139     161     188     230
# 17            Mizoram       0       0       0       0       0     177      55
# 18           Nagaland     164     132     166     215     202     272     344
# 19             Odisha     877     814    1191     997    1281    1410    1730
# 20             Punjab     817     996    1122    1434    1726    1963    1829
# 21          Rajasthan    1120    1360    1419    1585    1838    2116    2557
# 22             Sikkim      43      45      47      67      76     104     115
# 23         Tamil Nadu    1686    2006    2292    2752    2950    3309    3612
# 24          Telangana       0       0       0       0       0       0       0
# 25            Tripura     143     124     145     188     204     259     300
# 26      Uttar Pradesh    2668    2942    3490    4116    5186    5331    6225
# 27        Uttarakhand       0       0       0       0       0       0       0
# 28        West Bengal    1552    1838    2072    2181    2738    2974    3508
# 29              Delhi       0       0       0       0       0       0       0
# 30         Puducherry       0       0       0       0       0       0       0
#
#    1987-88 1988-89  ... 2006-07 2007-08    2008-09   2009-10    2010-11  \
# 0     4294    5223  ...   56648   74875   80803.89  85074.79  100635.64
# 1      348     326  ...    2786    3068    4272.59   5236.62    5579.12
# 2     1794    1855  ...   13485   15150   17485.86   24968.3   25946.97
# 3     3914    4324  ...   27136   31573   37181.25  42796.03   50704.52
# 4        0       0  ...   11991   15029   17713.97  21558.72   23564.68
# 5      258     284  ...    3176    3559    4517.43   5524.45     6228.9
# 6     4089    4374  ...   39200   42681   51897.42  60335.23   71606.61
# 7     1663    1879  ...   19638   22079   26368.17  32561.93   34434.23
# 8      805     985  ...   10091   10614   12492.35  14030.92   16131.28
# 9     1269    1404  ...   13873   17046   18749.89  22518.56   25568.92
# 10       0       0  ...   15726   18360   20641.47  22712.77   26502.04
# 11    3437    3778  ...   44085   48031   54038.82  62963.51   71934.09
# 12    2251    2521  ...   23159   28692    32553.5  35833.48   40765.26
# 13    3932    4596  ...   30217   35265   40030.26  50032.45   60055.18
# 14    6929    8102  ...   75841   80240   99068.48  117431.1  130155.42
# 15     319     393  ...    3626    3720    4403.77   4725.83    6114.87
# 16     264     318  ...    2320    2771    3432.71   3833.36    4770.19
# 17     306     287  ...    2295    2559    2868.54   3529.02     4139.5
# 18     436     457  ...    3085    3563    3949.46    4520.1    5576.04
# 19    1990    2261  ...   19346   22844   30051.73  30540.64   36051.31
# 20    2623    2666  ...   26297   26519   28785.71  31307.95   37060.03
# 21    3384    3415  ...   31856   37757   42968.24  48749.81   53703.32
# 22     139     164  ...    2253    2820    2981.91   3509.84    3437.58
# 23    4196    4617  ...   51147   55748   67723.09  72730.33   90881.74
# 24       0       0  ...       0       0          0         0          0
# 25     393     492  ...    3301    3835    4511.04   5757.51    5624.33
# 26    6901    8079  ...   74983   87304  104398.11  121115.3  134585.83
# 27       0       0  ...    8516    9975   10888.79  13297.14   14009.97
# 28    3941    4279  ...   41203   46644   60933.12  68134.03   72962.17
# 29       0       0  ...   12966   18160    20361.3  24925.92   25524.32
# 30       0       0  ...    2387    2588     2956.6   3585.83    4060.98
#
#       2011-12    2012-13    2013-14 2014-15 (RE) 2015-16 (BE)
# 0   115881.55  129440.92  136629.27    111067.46    112048.99
# 1     6665.17    6353.56    7781.63     11482.51     12712.91
# 2    30268.93   33747.64    37178.4     64979.96     63602.17
# 3    60180.03   69206.57   80405.17    132186.89    120685.32
# 4    28720.69   34819.25   39441.94     55979.35     65810.70
# 5     6953.57    7346.45     8149.5     10131.41     13102.77
# 6    79414.19   98281.32  104720.58    125490.25    137518.73
# 7    39751.43   46511.92   48928.65     63772.43     71674.80
# 8    17328.51   20714.59   21271.18     24894.61     28338.62
# 9    29856.23   31778.03    31908.7     42471.21     45919.52
# 10   26007.07   30399.82   30063.74     50839.55     55492.95
# 11   85756.16   96601.17   110648.7    132835.44    140534.43
# 12   53789.14   62032.26   69369.89     82947.71     99277.74
# 13   80658.96   83497.32   89764.16    123389.57    135972.07
# 14  148728.37  164202.42  186829.82    227932.63    240026.09
# 15    6862.64     6993.2    7172.92     11177.67      9652.41
# 16    5945.06     6123.4    6811.01     11893.17      9583.25
# 17    5638.11     5335.5    5635.93      7523.22      7576.53
# 18    6448.47    7194.14    7227.16      9241.40     10582.20
# 19    42105.1   47255.62   56130.92     76127.06     84487.77
# 20   36810.32   44507.28   47656.37     56430.95     61813.86
# 21   65372.08   81263.91   94101.08    125811.63    137713.39
# 22    3943.73    3930.92    4469.04      6716.29      5525.73
# 23  109465.27   121395.9  134192.38    161424.09    182338.58
# 24          0          0          0     99957.97    115059.19
# 25    6437.75    7027.49    7825.38     12399.45     14948.92
# 26  153712.31  173720.21  200720.05    262302.82    292687.32
# 27   16232.36   19216.41   21523.23     31455.80     31893.64
# 28   83830.88    95357.5  108513.39    129647.46    138374.00
# 29   26402.43   29858.81    34051.6     34790.00     41129.00
# 30    3756.01    3556.17    5050.33      5917.99      6431.00
#
# [31 rows x 37 columns]

# %%
for i in range(columns):
    print(str(i)+". :", df.iloc[:,i].dtype)
# Out:
# 0. : object
# 1. : object
# 2. : object
# 3. : object
# 4. : object
# 5. : object
# 6. : object
# 7. : object
# 8. : object
# 9. : object
# 10. : object
# 11. : object
# 12. : object
# 13. : object
# 14. : object
# 15. : object
# 16. : object
# 17. : object
# 18. : object
# 19. : object
# 20. : object
# 21. : object
# 22. : object
# 23. : object
# 24. : object
# 25. : object
# 26. : object
# 27. : object
# 28. : object
# 29. : object
# 30. : object
# 31. : object
# 32. : object
# 33. : object
# 34. : object
# 35. : float64
# 36. : float64

# %%
lst = []
col = df.columns
print(col)
for i in col:
    if i!="State":
        lst.append(i)
print(lst)
# Out:
# Index(['State', '1980-81', '1981-82', '1982-83', '1983-84', '1984-85',
#        '1985-86', '1986-87', '1987-88', '1988-89', '1989-90', '1990-91',
#        '1991-92', '1992-93', '1993-94', '1994-95', '1995-96', '1996-97',
#        '1997-98', '1998-99', '1999-00', '2000-01', '2001-02', '2002-03',
#        '2003-04', '2004-05', '2005-06', '2006-07', '2007-08', '2008-09',
#        '2009-10', '2010-11', '2011-12', '2012-13', '2013-14', '2014-15 (RE)',
#        '2015-16 (BE)'],
#       dtype='object')
# ['1980-81', '1981-82', '1982-83', '1983-84', '1984-85', '1985-86', '1986-87', '1987-88', '1988-89', '1989-90', '1990-91', '1991-92', '1992-93', '1993-94', '1994-95', '1995-96', '1996-97', '1997-98', '1998-99', '1999-00', '2000-01', '2001-02', '2002-03', '2003-04', '2004-05', '2005-06', '2006-07', '2007-08', '2008-09', '2009-10', '2010-11', '2011-12', '2012-13', '2013-14', '2014-15 (RE)', '2015-16 (BE)']

# %%
df[lst] = df[lst].apply(pd.to_numeric)

# %%
for i in range(columns):
    print(str(i)+". :", df.iloc[:,i].dtype)
# Out:
# 0. : object
# 1. : int64
# 2. : int64
# 3. : int64
# 4. : int64
# 5. : int64
# 6. : int64
# 7. : int64
# 8. : int64
# 9. : int64
# 10. : int64
# 11. : int64
# 12. : int64
# 13. : int64
# 14. : int64
# 15. : int64
# 16. : int64
# 17. : int64
# 18. : int64
# 19. : int64
# 20. : int64
# 21. : int64
# 22. : int64
# 23. : int64
# 24. : int64
# 25. : int64
# 26. : int64
# 27. : int64
# 28. : int64
# 29. : float64
# 30. : float64
# 31. : float64
# 32. : float64
# 33. : float64
# 34. : float64
# 35. : float64
# 36. : float64

# %%
import seaborn as sns

plt.figure(figsize=(30,10))
sns.barplot(x='1980-81',y="State",data=df)
# Out:
# <Axes: xlabel='1980-81', ylabel='State'>

# %%
for i in lst:
    plt.xlabel(i)
    plt.ylabel("State")
    plt.title(i+" vs State")
    plt.figure(figsize=(30,10))
    sns.barplot(x=i,y="State",data=df)
# Out:
# /var/folders/qh/215l544s06x3_jp987f9gdgh0000gn/T/ipykernel_58407/1493585771.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(30,10))

# %%
for i in lst:
    plt.xlabel(i)
    plt.ylabel("State")
    plt.title(i+" vs State")
    plt.figure(figsize=(30,10))
    ax = sns.barplot(x="State",y = i,data=df)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
    #plt.tight_layout()
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
scalar = StandardScaler()
dr = scalar.fit_transform(df.iloc[:,1:])
print(dr)
# Out:
# [[ 1.10880545  1.12899783  0.9679781  ...  1.4746085   0.56324865
#    0.44645214]
#  [-0.92241055 -0.89965283 -0.89232183 ... -0.88958339 -0.96220487
#   -0.95498235]
#  [ 0.03390108 -0.21494169 -0.22731032 ... -0.35018969 -0.14272488
#   -0.23703612]
#  ...
#  [ 1.03563121  1.13675346  1.10175032 ...  0.95871752  0.84785919
#    0.81784566]
#  [-0.92241055 -0.89965283 -0.89232183 ... -0.40756253 -0.6051781
#   -0.55408785]
#  [-0.92241055 -0.89965283 -0.89232183 ... -0.9396993  -1.04744282
#   -1.0436076 ]]

# %%
pca = PCA(n_components=2)
dr_pca = pca.fit_transform(dr)
dr_pca
# Out:
# array([[ 8.16041232, -1.3010397 ],
#        [-5.19296809,  0.1796433 ],
#        [-1.42708543,  0.58104943],
#        [ 3.75054291,  1.82462281],
#        [-4.24065509, -1.27002373],
#        [-5.11672732,  0.0978087 ],
#        [ 5.48920452, -0.02517969],
#        [-0.56304606,  0.068666  ],
#        [-3.37540657,  0.13767457],
#        [-2.15402226,  0.06445176],
#        [-4.13650612, -1.50112278],
#        [ 4.86830882, -0.44419876],
#        [ 1.06531827,  0.10085017],
#        [ 4.52312144,  1.11615567],
#        [15.24118461, -0.13887093],
#        [-4.95340052,  0.32194016],
#        [-5.12413393,  0.33543389],
#        [-5.28695676,  0.23297783],
#        [-4.88742001,  0.40940052],
#        [-0.06593027,  0.28776896],
#        [ 0.83735032,  0.3894872 ],
#        [ 3.41178412,  0.02013445],
#        [-5.2800054 ,  0.20437849],
#        [ 7.5647492 , -0.18292902],
#        [-5.36139469,  0.3640084 ],
#        [-4.84114034,  0.32850809],
#        [15.33906996,  0.0544398 ],
#        [-4.86944518, -0.69345289],
#        [ 5.84043875, -0.31297527],
#        [-3.53502715, -1.38081033],
#        [-5.68021407,  0.13120291]])

# %%
dr_pca_dataframe = pd.DataFrame(dr_pca,columns=["pca_column_1","pca_column_2"])
dr_pca_dataframe
# Out:
#     pca_column_1  pca_column_2
# 0       8.160412     -1.301040
# 1      -5.192968      0.179643
# 2      -1.427085      0.581049
# 3       3.750543      1.824623
# 4      -4.240655     -1.270024
# 5      -5.116727      0.097809
# 6       5.489205     -0.025180
# 7      -0.563046      0.068666
# 8      -3.375407      0.137675
# 9      -2.154022      0.064452
# 10     -4.136506     -1.501123
# 11      4.868309     -0.444199
# 12      1.065318      0.100850
# 13      4.523121      1.116156
# 14     15.241185     -0.138871
# 15     -4.953401      0.321940
# 16     -5.124134      0.335434
# 17     -5.286957      0.232978
# 18     -4.887420      0.409401
# 19     -0.065930      0.287769
# 20      0.837350      0.389487
# 21      3.411784      0.020134
# 22     -5.280005      0.204378
# 23      7.564749     -0.182929
# 24     -5.361395      0.364008
# 25     -4.841140      0.328508
# 26     15.339070      0.054440
# 27     -4.869445     -0.693453
# 28      5.840439     -0.312975
# 29     -3.535027     -1.380810
# 30     -5.680214      0.131203

# %%
df1 = pd.concat([dr_pca_dataframe,df.iloc[:,0]],axis=1).reset_index()
df1
# Out:
#     index  pca_column_1  pca_column_2              State
# 0       0      8.160412     -1.301040    Andhra Pradesh
# 1       1     -5.192968      0.179643  Arunachal Pradesh
# 2       2     -1.427085      0.581049              Assam
# 3       3      3.750543      1.824623              Bihar
# 4       4     -4.240655     -1.270024       Chhattisgarh
# 5       5     -5.116727      0.097809                Goa
# 6       6      5.489205     -0.025180            Gujarat
# 7       7     -0.563046      0.068666            Haryana
# 8       8     -3.375407      0.137675   Himachal Pradesh
# 9       9     -2.154022      0.064452    Jammu & Kashmir
# 10     10     -4.136506     -1.501123          Jharkhand
# 11     11      4.868309     -0.444199          Karnataka
# 12     12      1.065318      0.100850             Kerala
# 13     13      4.523121      1.116156     Madhya Pradesh
# 14     14     15.241185     -0.138871        Maharashtra
# 15     15     -4.953401      0.321940            Manipur
# 16     16     -5.124134      0.335434          Meghalaya
# 17     17     -5.286957      0.232978            Mizoram
# 18     18     -4.887420      0.409401           Nagaland
# 19     19     -0.065930      0.287769             Odisha
# 20     20      0.837350      0.389487             Punjab
# 21     21      3.411784      0.020134          Rajasthan
# 22     22     -5.280005      0.204378             Sikkim
# 23     23      7.564749     -0.182929         Tamil Nadu
# 24     24     -5.361395      0.364008          Telangana
# 25     25     -4.841140      0.328508            Tripura
# 26     26     15.339070      0.054440      Uttar Pradesh
# 27     27     -4.869445     -0.693453        Uttarakhand
# 28     28      5.840439     -0.312975        West Bengal
# 29     29     -3.535027     -1.380810              Delhi
# 30     30     -5.680214      0.131203         Puducherry
